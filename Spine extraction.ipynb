# %% [markdown]
# # Spine extraction from spine-only mesh

# %%
#read and visualize spine only mesh 
import pyvista as pv 

mesh = pv.read("test1.vtu") 
mesh
mesh.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x2534C051DA0>

# %%
#split mesh to individual spines
spines=mesh.split_bodies()
